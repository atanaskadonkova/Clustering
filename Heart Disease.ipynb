# %% [markdown]
# # Heart Disease

# %%
# A) Data Analysis:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# a. Import the dataset

# %%
df = pd.read_csv("./Desktop/Heart disease.csv") 
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
# b. Get information about dataset (mean, max, min, quartiles etc.)

df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
# Calculate quartiles
q1 = np.percentile(df, 25)
q2 = np.percentile(df, 50)
q3 = np.percentile(df, 75)

# Output quartiles
print("Q1 (25th percentile):", q1)
print("Q2 (50th percentile, median):", q2)
print("Q3 (75th percentile):", q3)
# Out:
# Q1 (25th percentile): 0.0
# Q2 (50th percentile, median): 1.0
# Q3 (75th percentile): 55.0

# %%
# c. Find the correlation between all fields.

df.corr()
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.098447 -0.068653  0.279351  0.213678  0.121308
# sex      -0.098447  1.000000 -0.049353 -0.056769 -0.197912  0.045032
# cp       -0.068653 -0.049353  1.000000  0.047608 -0.076904  0.094444
# trestbps  0.279351 -0.056769  0.047608  1.000000  0.123174  0.177531
# chol      0.213678 -0.197912 -0.076904  0.123174  1.000000  0.013294
# fbs       0.121308  0.045032  0.094444  0.177531  0.013294  1.000000
# restecg  -0.116211 -0.058196  0.044421 -0.114103 -0.151040 -0.084189
# thalach  -0.398522 -0.044020  0.295762 -0.046698 -0.009940 -0.008567
# exang     0.096801  0.141664 -0.394280  0.067616  0.067023  0.025665
# oldpeak   0.210013  0.096093 -0.149230  0.193216  0.053952  0.005747
# slope    -0.168814 -0.030711  0.119717 -0.121475 -0.004038 -0.059894
# ca        0.276326  0.118261 -0.181053  0.101389  0.070511  0.137979
# thal      0.068001  0.210041 -0.161736  0.062210  0.098803 -0.032019
# ...

# %%
# B) Data Visualization:

# %%
# a. Visualize the number of patients having a heart disease and not having a heart disease
heart_disease_counts = df['target'].value_counts()
plt.figure(figsize=(6, 4))
sns.countplot(x='target', data=df)
plt.xlabel('Heart Disease')
plt.ylabel('Count')
plt.title('Number of Patients with and without Heart Disease')
plt.show()

# %%
# b. Visualize the age and whether the patient has a disease or not
plt.figure(figsize=(10, 6))
sns.boxplot(x='target', y='age', data=df)
plt.xlabel('Heart Disease')
plt.ylabel('Age')
plt.title('Age Distribution for Patients with and without Heart Disease')
plt.show()

# %%
# c. Visualize correlation between all features using a heat map
plt.figure(figsize=(10, 8))
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Between Features')
plt.show()

# %%
# C) Logistic Regression:

# %%
# Check for missing values
missing_values = df.isnull().sum()
print(missing_values)
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
# a. Build a simple logistic regression model

X = df[['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal']]
y = df['target']

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
# i. Split the dataset into 70:30 ratio
X_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# ii. Build the logistic regression model on the training set 
logreg = LogisticRegression()
logreg.fit(X_train, y_train)
# Out:
# /Users/atanaska/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
# predict the values on the test set

y_pred = logreg.predict(x_test)

# %%
# iii. Build the confusion matrix and get the accuracy score

from sklearn.metrics import accuracy_score
accuracy_score (y_train, logreg.predict(X_train))
# Out:
# 0.8679245283018868

# %%
accuracy_score (y_test, logreg.predict(x_test))
# Out:
# 0.8131868131868132

# %%
# iii. Build the confusion matrix
from sklearn.metrics import confusion_matrix, accuracy_score

cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(cm)

# Get the accuracy score
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy_score:", accuracy)
# Out:
# Confusion Matrix:
# [[32  9]
#  [ 8 42]]
# Accuracy_score: 0.8131868131868132

# %%
# D) Decision Tree:

# %%
# a. Build a decision tree model
# i. Divide the dataset in 70:30 ratio
from sklearn.model_selection import train_test_split
X_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# ii. Build the model on train set and -

from sklearn.tree import DecisionTreeClassifier

clf = DecisionTreeClassifier()
clf.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
# - Predict the values on the test set
y_pred = clf.predict(x_test)

# %%
# iii. Build the confusion matrix and calculate the accuracy
from sklearn.metrics import  confusion_matrix,accuracy_score

cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(cm)

# Get the accuracy score
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy_score:", accuracy)
# Out:
# Confusion Matrix:
# [[33  8]
#  [18 32]]
# Accuracy_score: 0.7142857142857143

# %%
# !pip install graphviz
# !pip install --upgrade pip
# !sudo apt-get install graphviz

# %%
# !pip3 install graphviz 
# !brew install graphviz
# Out:
# ...
# ==> Downloading https://formulae.brew.sh/api/formula.jws.json
# #=#=#
# ==> Downloading https://formulae.brew.sh/api/cask.jws.json
# #=#=#
# ...
# To reinstall 8.0.5, run:
#   brew reinstall graphviz

# %%
# iv. Visualize the decision tree using the graphviz package

from sklearn.tree import export_graphviz
import graphviz

dot_data = export_graphviz(clf, out_file=None, feature_names=X.columns)
graph = graphviz.Source(dot_data)
graph.render("decision_tree")  # Save the decision tree visualization as a file (optional)
graph.view()  # Display the decision tree visualization
# Out:
# 'decision_tree.pdf'

# %%
# E) Random Forest:

# %%
# i. Divide the dataset in 70:30 ratio

X_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.30)

# %%
# ii. Build the model on train set and predict the values on test set

# %%
# iii. Build the confusion matrix and calculate the accuracy
from sklearn.ensemble import RandomForestClassifier
clf=RandomForestClassifier(n_estimators=100)
clf.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred=clf.predict(x_test)

from sklearn import metrics
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8131868131868132

# %%
# iv. Visualize the model using the graphviz package
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import export_graphviz
import graphviz



# Get an individual decision tree from the random forest
tree = clf.estimators_[0]  # Change the index to select a different tree

# Export the decision tree to DOT format
dot_data = export_graphviz(tree, out_file=None, feature_names=['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal'])
graph = graphviz.Source(dot_data)
graph.view()
# Out:
# 'Source.gv.pdf'

# %%
# F) Select the best model

# %%
# a. Print the confusion matrix of all classifiers

classifiers = [logreg, clf, tree]  # List of trained classifiers
test_data = X_test  # Test data used for evaluation
test_labels = y_test  # True labels for the test data

for clf in classifiers:
    y_pred = clf.predict(test_data)
    cm = confusion_matrix(test_labels, y_pred)
    print("Confusion Matrix for", clf.__class__.__name__)
    print(cm)
    print()
# Out:
# Confusion Matrix for LogisticRegression
# [[13 30]
#  [27 21]]
#
# Confusion Matrix for RandomForestClassifier
# [[15 28]
#  [23 25]]
#
# Confusion Matrix for DecisionTreeClassifier
# [[20 23]
#  [25 23]]
# /Users/atanaska/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:443: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(

# %%
# b. Print the classification report of all classifiers

from sklearn.metrics import classification_report

for clf in classifiers:
    y_pred = clf.predict(test_data)
    report = classification_report(test_labels, y_pred)
    print("Classification Report for", clf.__class__.__name__)
    print(report)
    print()
# Out:
# Classification Report for LogisticRegression
#               precision    recall  f1-score   support
#
#            0       0.33      0.30      0.31        43
#            1       0.41      0.44      0.42        48
#
#     accuracy                           0.37        91
#    macro avg       0.37      0.37      0.37        91
# weighted avg       0.37      0.37      0.37        91
#
#
# Classification Report for RandomForestClassifier
#               precision    recall  f1-score   support
#
#            0       0.39      0.35      0.37        43
#            1       0.47      0.52      0.50        48
#
#     accuracy                           0.44        91
#    macro avg       0.43      0.43      0.43        91
# weighted avg       0.44      0.44      0.44        91
#
#
# Classification Report for DecisionTreeClassifier
#               precision    recall  f1-score   support
#
#            0       0.44      0.47      0.45        43
# ...

# %%
# c. Calculate Recall Precision and F1 score of all the models

for clf in classifiers:
    y_pred = clf.predict(test_data)
    report = classification_report(test_labels, y_pred, output_dict=True)
    recall = report['macro avg']['recall']
    precision = report['macro avg']['precision']
    f1_score = report['macro avg']['f1-score']
    print("Metrics for", clf.__class__.__name__)
    print("Recall:", recall)
    print("Precision:", precision)
    print("F1-Score:", f1_score)
    print()
# Out:
# Metrics for LogisticRegression
# Recall: 0.3699127906976744
# Precision: 0.3683823529411765
# F1-Score: 0.3687477181453085
#
# Metrics for RandomForestClassifier
# Recall: 0.4348352713178295
# Precision: 0.43321747765640517
# F1-Score: 0.43270993766043275
#
# Metrics for DecisionTreeClassifier
# Recall: 0.47214147286821706
# Precision: 0.4722222222222222
# F1-Score: 0.47195357833655704
# /Users/atanaska/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:443: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(

# %%
# d. Visualize confusion matrix using heatmaps

for clf in classifiers:
    y_pred = clf.predict(test_data)
    cm = confusion_matrix(test_labels, y_pred)
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, cmap="Blues")
    plt.title("Confusion Matrix for " + clf.__class__.__name__)
    plt.xlabel("Predicted Labels")
    plt.ylabel("True Labels")
    plt.show()
# Out:
# /Users/atanaska/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:443: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(

# %%
# e. Select the best model based on the best accuracies

best_accuracy = 0
best_model = None

for clf in classifiers:
    y_pred = clf.predict(test_data)
    accuracy = accuracy_score(test_labels, y_pred)
    if accuracy > best_accuracy:
        best_accuracy = accuracy
        best_model = clf

print("Best Model:", best_model.__class__.__name__)
print("Best Accuracy:", best_accuracy)
# Out:
# Best Model: DecisionTreeClassifier
# Best Accuracy: 0.4725274725274725
# /Users/atanaska/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:443: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
